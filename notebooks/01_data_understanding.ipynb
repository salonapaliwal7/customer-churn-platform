# %%
# Customer Churn Prediction Platform

# %% [markdown]
# # Customer churn refers to customers discontinuing a company's service. Telecom companies invest heavily in acquiring customers. This project aims to predict which customers are likely to churn using historical customer information. The resulting predictions can help businesses proactively target at-risk customers with retention strategies, reducing revenue loss and improving customer satisfaction.

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

pd.set_option("display.max_columns", None)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.sample(5, random_state=42)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 185            No  No phone service             DSL                   No
# 2715          Yes               Yes              No  No internet service
# 3825          Yes                No              No  No internet service
# 1807          Yes                No     Fiber optic                   No
# 132           Yes                No             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %% [markdown]
# Classify columns :
#
# - Identifier
#     customerID
# - Demographic
#     gender
#     SeniorCitizen
#     Partner
#     Dependents
# - Account
#     tenure
#     Contract
#     PaymentMethod
# - Services
#     InternetService
#     PhoneService
#     TechSupport
#     ...
# - Billing
#     MonthlyCharges
#     TotalCharges
# - Target
#     Churn

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe(include="number") # for numerical columns
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include="object") # for categorical columns
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
# find missing values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# find missing values percentage

missing = (
    df.isnull().sum()
      .sort_values(ascending=False)
      .to_frame(name="Missing Count")
)

missing["Missing %"] = (missing["Missing Count"] / len(df)) * 100

missing[missing["Missing Count"] > 0]
# Out:
# Empty DataFrame
# Columns: [Missing Count, Missing %]
# Index: []

# %%
# Check for duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check target variable distribution

df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# percentage distribution of target variable (to check data imbalance)

df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
#visualize the distribution of the target variable

sns.countplot(data=df, x="Churn")
plt.title("Distribution of Customer Churn")
plt.show()

# %% [markdown]
# # Initial Observations
#
# # Dataset has 7043 rows and 21 features (columns) - small dataset
# # Most features are categorical
# # Numerical Features : SeniorCitizen, tenure, MonthlyCharges
# # The target variable appears to be moderately imbalanced
# # Although there doesn't seem to be any missing values but there's a suspicioud column "TotalCharges" which is  string and has empty values
# # We will handle all this in our preprcessing step
